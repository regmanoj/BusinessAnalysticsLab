# %% [markdown]
# # Week – 2: Prediction Model
#
# ## Problem Statement
# Build a predictive model for determining height or weight of a person for given dataset.

# %% [markdown]
# ## Dataset Description
#
# The given dataset contains only 2 features height (inches) and weights (pounds)
#   of 25,000 different humans of 18 years of age. This dataset can be used to build a model that can predict the heights or weights of a human.
#
# The objective of this experiment is to **predict weight** using height as the predictor variable or dependent variable.

# %% [markdown]
# ## Procedure

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error

# Load data
df = pd.read_csv("SOCR-HeightWeight.csv")

X = df[["Height"]]
y = df["Weight"]

# Split data
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.2,random_state=42)

# Train model
model = LinearRegression()
model.fit(X_train,y_train)

# Predict
pred = model.predict(X_test)

# Metrics
r2 = r2_score(y_test,pred)
mae = mean_absolute_error(y_test,pred)
rmse = root_mean_squared_error(y_test,pred)

print("R2:",r2)
print("MAE:",mae)
print("RMSE:",rmse)


plt.scatter(y_test,pred)
plt.xlabel("Actual Weight")
plt.ylabel("Predicted Weight")
plt.title("Actual vs Predicted (Regression)")

# perfect prediction line
plt.plot([y_test.min(),y_test.max()],
         [y_test.min(),y_test.max()],
         color="red")

plt.show()


# Prediction example

ht = [[60]]
weight_predicted=model.predict(ht)
print("Predicted weight for a sample value : ",weight_predicted)
# Out:
# R2: 0.2514686758780984
# MAE: 8.056812852525603
# RMSE: 10.10965877299286
# Predicted weight for a sample value :  [102.21673139]
# C:\Users\Manoj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Results
# - The model's R² value is approximately 0.251, suggesting that 25.1% of the variance in weight can be explained by height. This indicates that height has some predictive power for weight but is not a strong predictor on its own.
#
# - The mean absolute error (MAE) of 8.06 lbs means that, on average, the model's predictions differ from the actual weights by about 8.06 lbs.
#
# - The root mean squared error (RMSE) is 10.11 lbs, indicating that the model's predictions, while relatively close, can sometimes be off by up to 10 lbs in some instances.
#
# - A prediction for a person with a height of 60 inches resulted in a predicted weight of 102.22 lbs.
